# %% [markdown]
# <a href="https://colab.research.google.com/github/UEPP40/PUM/blob/Maksim/PUM1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-75be31d8-1bba-4825-864b-7d1292752a91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75be31d8-1bba-4825-864b-7d1292752a91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
# <ipython-input-1-53016807beaa>:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# ...

# %%
df_train.drop_duplicates(inplace=True)

# %%
df_train.shape
# Out:
# (100000, 28)

# %%
df_train.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  string
#  3   Name                      90015 non-null   object
#  4   Age                       95061 non-null   Int64
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             93020 non-null   float64
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
df_train["Age"] = pd.to_numeric(df_train["Age"], errors='coerce').astype('Int64')

# %%
df_train['Month'] = (df_train['Month']).astype('string')
df_train['Annual_Income'] = pd.to_numeric(df_train['Annual_Income'], errors='coerce').astype('float64')
df_train['Num_of_Loan'] = pd.to_numeric(df_train['Num_of_Loan'], errors='coerce').astype('Int64')
df_train['Num_of_Delayed_Payment'] = pd.to_numeric(df_train['Num_of_Delayed_Payment'], errors='coerce').astype('Int64')
df_train['Changed_Credit_Limit'] = pd.to_numeric(df_train['Changed_Credit_Limit'], errors='coerce').astype('float64')
df_train['Outstanding_Debt'] = pd.to_numeric(df_train['Outstanding_Debt'], errors='coerce').astype('float64')
df_train['Amount_invested_monthly'] = pd.to_numeric(df_train['Amount_invested_monthly'], errors='coerce').astype('float64')
df_train['Monthly_Balance'] = pd.to_numeric(df_train['Monthly_Balance'], errors='coerce').astype('float64')

# %%
df_train.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        string
# Name                         object
# Age                           Int64
# SSN                          object
# Occupation                   object
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                   Int64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment        Int64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import math

# %%
df_train = df_train.drop(["ID", "Customer_ID", "Name", "SSN"], axis=1)

# %%
df_train.shape
# Out:
# (100000, 24)

# %%
df_train.columns
# Out:
# Index(['Month', 'Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
if_null = df_train.isnull().any()
print(if_null)
# Out:
# Month                       False
# Age                          True
# Occupation                  False
# Annual_Income                True
# Monthly_Inhand_Salary        True
# Num_Bank_Accounts           False
# Num_Credit_Card             False
# Interest_Rate               False
# Num_of_Loan                  True
# Type_of_Loan                 True
# Delay_from_due_date         False
# Num_of_Delayed_Payment       True
# Changed_Credit_Limit         True
# Num_Credit_Inquiries         True
# Credit_Mix                  False
# Outstanding_Debt             True
# Credit_Utilization_Ratio    False
# Credit_History_Age           True
# Payment_of_Min_Amount       False
# Total_EMI_per_month         False
# Amount_invested_monthly      True
# Payment_Behaviour           False
# Monthly_Balance              True
# Credit_Score                False
# dtype: bool

# %%
df_train["Annual_Income"] = df_train["Annual_Income"].fillna(df_train["Annual_Income"].mean().round())
df_train["Monthly_Inhand_Salary"] = df_train["Monthly_Inhand_Salary"].fillna(df_train["Monthly_Inhand_Salary"].mean().round())
df_train["Num_of_Loan"] = df_train["Num_of_Loan"].fillna(df_train["Num_of_Loan"].mean().round())
df_train["Num_of_Delayed_Payment"] = df_train["Num_of_Delayed_Payment"].fillna(df_train["Num_of_Delayed_Payment"].mean().round())
df_train["Changed_Credit_Limit"] = df_train["Changed_Credit_Limit"].fillna(df_train["Changed_Credit_Limit"].mean().round())
df_train["Num_Credit_Inquiries"] = df_train["Num_Credit_Inquiries"].fillna(df_train["Num_Credit_Inquiries"].mean().round())
df_train["Outstanding_Debt"] = df_train["Outstanding_Debt"].fillna(df_train["Outstanding_Debt"].mean().round())
df_train["Amount_invested_monthly"] = df_train["Amount_invested_monthly"].fillna(df_train["Amount_invested_monthly"].mean().round())
df_train["Monthly_Balance"] = df_train["Monthly_Balance"].fillna(df_train["Monthly_Balance"].mean().round())

# %%
df_train["Age"] = df_train["Age"].fillna(df_train["Age"].mean().round())

# %%
if_null = df_train.isnull().any()
print(if_null)
# Out:
# Month                       False
# Age                         False
# Occupation                  False
# Annual_Income               False
# Monthly_Inhand_Salary       False
# Num_Bank_Accounts           False
# Num_Credit_Card             False
# Interest_Rate               False
# Num_of_Loan                 False
# Type_of_Loan                 True
# Delay_from_due_date         False
# Num_of_Delayed_Payment      False
# Changed_Credit_Limit        False
# Num_Credit_Inquiries        False
# Credit_Mix                  False
# Outstanding_Debt            False
# Credit_Utilization_Ratio    False
# Credit_History_Age           True
# Payment_of_Min_Amount       False
# Total_EMI_per_month         False
# Amount_invested_monthly     False
# Payment_Behaviour           False
# Monthly_Balance             False
# Credit_Score                False
# dtype: bool

# %%
most_common_in_column = df_train["Month"].value_counts().idxmax()
print("Most common value in a column Month is", most_common_in_column)
# Out:
# Most common value in a column Month is January

# %%
df_train["Month"].fillna("January", inplace = True)

# %%
if_null = df_train.isnull().any()
print(if_null)
# Out:
# Month                       False
# Age                         False
# Occupation                  False
# Annual_Income               False
# Monthly_Inhand_Salary       False
# Num_Bank_Accounts           False
# Num_Credit_Card             False
# Interest_Rate               False
# Num_of_Loan                 False
# Type_of_Loan                 True
# Delay_from_due_date         False
# Num_of_Delayed_Payment      False
# Changed_Credit_Limit        False
# Num_Credit_Inquiries        False
# Credit_Mix                  False
# Outstanding_Debt            False
# Credit_Utilization_Ratio    False
# Credit_History_Age           True
# Payment_of_Min_Amount       False
# Total_EMI_per_month         False
# Amount_invested_monthly     False
# Payment_Behaviour           False
# Monthly_Balance             False
# Credit_Score                False
# dtype: bool

# %%
df_train = df_train.drop(["Type_of_Loan", "Credit_History_Age"], axis=1)

# %%
redundant_values = ['-', '_']

for column in df_train.columns:
    # Check if any of the redundant values exist in the column
    redundant_in_column = any(df_train[column].isin(redundant_values))
    print(redundant_in_column)

    if redundant_in_column:
        print(f"Column '{column}' contains redundant values.")
    else:
        print(f"Column '{column}' does not contain redundant values.")
# Out:
# False
# Column 'Month' does not contain redundant values.
# False
# Column 'Age' does not contain redundant values.
# False
# Column 'Occupation' does not contain redundant values.
# False
# Column 'Annual_Income' does not contain redundant values.
# False
# Column 'Monthly_Inhand_Salary' does not contain redundant values.
# False
# Column 'Num_Bank_Accounts' does not contain redundant values.
# False
# Column 'Num_Credit_Card' does not contain redundant values.
# False
# Column 'Interest_Rate' does not contain redundant values.
# False
# Column 'Num_of_Loan' does not contain redundant values.
# False
# Column 'Delay_from_due_date' does not contain redundant values.
# False
# Column 'Num_of_Delayed_Payment' does not contain redundant values.
# False
# Column 'Changed_Credit_Limit' does not contain redundant values.
# False
# Column 'Num_Credit_Inquiries' does not contain redundant values.
# False
# Column 'Credit_Mix' does not contain redundant values.
# False
# ...

# %%
df_train["Credit_Mix"] = df_train["Credit_Mix"].str.strip('-_')

# %%
if_null = df_train.isnull().any()
print(if_null)
# Out:
# Month                       False
# Age                         False
# Occupation                  False
# Annual_Income               False
# Monthly_Inhand_Salary       False
# Num_Bank_Accounts           False
# Num_Credit_Card             False
# Interest_Rate               False
# Num_of_Loan                 False
# Delay_from_due_date         False
# Num_of_Delayed_Payment      False
# Changed_Credit_Limit        False
# Num_Credit_Inquiries        False
# Credit_Mix                  False
# Outstanding_Debt            False
# Credit_Utilization_Ratio    False
# Payment_of_Min_Amount       False
# Total_EMI_per_month         False
# Amount_invested_monthly     False
# Payment_Behaviour           False
# Monthly_Balance             False
# Credit_Score                False
# dtype: bool

# %%
df_train.dtypes
# Out:
# Month                        string
# Age                           Int64
# Occupation                   object
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                   Int64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment        Int64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# dtype: object

# %%
df_train['Num_of_Delayed_Payment'].fillna(0, inplace=True)

# %%
df_train.head(50)
# Out:
#        Month   Age    Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0    January    23     Scientist       19114.12            1824.843333
# 1   February    23     Scientist       19114.12            4194.000000
# 2      March  -500     Scientist       19114.12            4194.000000
# 3      April    23     Scientist       19114.12            4194.000000
# 4        May    23     Scientist       19114.12            1824.843333
# 5       June    23     Scientist       19114.12            4194.000000
# 6       July    23     Scientist       19114.12            1824.843333
# 7     August    23     Scientist       19114.12            1824.843333
# 8    January   111       _______       34847.84            3037.986667
# 9   February    28       Teacher       34847.84            3037.986667
# 10     March    28       Teacher      178579.00            3037.986667
# 11     April    28       Teacher       34847.84            4194.000000
# ...

# %%
df_train['Age'] = df_train['Age'].abs()

# %%
avg_age = df_train["Age"].mean()
print(avg_age)
# Out:
# 119.79774

# %%
df_train.loc[(df_train['Age'] > 100) | (df_train['Age'] < 18), 'Age'] = 34

# %%
avg_age = df_train["Age"].mean()
print(avg_age)
# Out:
# 34.37067

# %%
df_train.head(6000)
# Out:
#          Month  Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      January   23      Scientist       19114.12            1824.843333
# 1     February   23      Scientist       19114.12            4194.000000
# 2        March   34      Scientist       19114.12            4194.000000
# 3        April   23      Scientist       19114.12            4194.000000
# 4          May   23      Scientist       19114.12            1824.843333
# ...        ...  ...            ...            ...                    ...
# 5995     April   30  Media_Manager       73747.58            6166.631667
# 5996       May   30  Media_Manager       73747.58            6166.631667
# 5997      June   30  Media_Manager       73747.58            6166.631667
# 5998      July   30  Media_Manager      178579.00            6166.631667
# 5999    August   30  Media_Manager       73747.58            4194.000000
#
#       Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# ...

# %%
df_train.loc[df_train["Num_of_Loan"] < 0, "Num_of_Loan"] = 3

# %%
import numpy as np

# %%
numeric_columns = ['Age','Annual_Income','Num_of_Loan','Num_of_Delayed_Payment'
,'Changed_Credit_Limit','Outstanding_Debt',
'Amount_invested_monthly','Monthly_Balance', 'Num_Bank_Accounts','Num_Credit_Card', 'Interest_Rate', 'Delay_from_due_date',
  'Num_Credit']

# %%
integer_columns = df_train.columns[df_train.dtypes == 'int64']
print(integer_columns)
# Out:
# Index(['Occupation', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate',
#        'Delay_from_due_date', 'Credit_Mix', 'Payment_Behaviour',
#        'Credit_Score'],
#       dtype='object')

# %%
columns = ["Occupation","Credit_Mix", "Payment_Behaviour", "Credit_Score"]
# Encode labels of multiple columns at once
df_train[columns] =df_train[columns].apply(LabelEncoder().fit_transform)

# %%
df_train.head(50)
# Out:
#        Month  Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0    January   23          12       19114.12            1824.843333
# 1   February   23          12       19114.12            4194.000000
# 2      March   34          12       19114.12            4194.000000
# 3      April   23          12       19114.12            4194.000000
# 4        May   23          12       19114.12            1824.843333
# 5       June   23          12       19114.12            4194.000000
# 6       July   23          12       19114.12            1824.843333
# 7     August   23          12       19114.12            1824.843333
# 8    January   34          15       34847.84            3037.986667
# 9   February   28          13       34847.84            3037.986667
# 10     March   28          13      178579.00            3037.986667
# 11     April   28          13       34847.84            4194.000000
# 12       May   28          13       34847.84            3037.986667
# ...

# %%
df_train.dtypes
# Out:
# Month                        string
# Age                           Int64
# Occupation                    int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                   Int64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment        Int64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                    int64
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour             int64
# Monthly_Balance             float64
# Credit_Score                  int64
# dtype: object
