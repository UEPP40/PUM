# %% [markdown]
# <a href="https://colab.research.google.com/github/UEPP40/PUM/blob/ostrowska/regresjaZadanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
from sklearn.preprocessing import LabelEncoder

df.dropna(inplace=True)
le = LabelEncoder()

columns = ["Gender", "Education Level", "Job Title"]
df[columns] = df[columns].apply(LabelEncoder().fit_transform)

df.head()
# Out:
#     Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0  32.0       1                0        159                  5.0   90000.0
# 1  28.0       0                1         17                  3.0   65000.0
# 2  45.0       1                2        130                 15.0  150000.0
# 3  36.0       0                0        101                  7.0   60000.0
# 4  52.0       1                1         22                 20.0  200000.0

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#podział danych
train_df, test_df = train_test_split(df ,test_size=0.3, random_state=42)

X_train = train_df[["Age", "Gender", "Education Level", "Job Title", "Years of Experience"]]
Y_train = train_df["Salary"]
X_test = test_df[["Age", "Gender", "Education Level", "Job Title", "Years of Experience"]]
Y_test = test_df["Salary"]

# %%
model=LinearRegression().fit(X_train,Y_train)
model.score(X_train,Y_train)
model.coef_
model.intercept_
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
Y_true = Y_test
mean_absolute_error(Y_true,Y_pred)
# Out:
# 11377.183126703107

# %%
from sklearn.metrics import median_absolute_error
Y_true = Y_test
median_absolute_error(Y_true,Y_pred)
# Out:
# 8320.821301534226

# %%
from sklearn.metrics import r2_score
Y_true = Y_test
r2_score(Y_true,Y_pred)
# Out:
# 0.8882126073587826
