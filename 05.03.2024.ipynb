# %% [markdown]
# <a href="https://colab.research.google.com/github/UEPP40/PUM/blob/Jablonski/05.03.2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import math
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
train = pd.read_csv('train.csv')
##train.info()
train.drop_duplicates(subset='ID',inplace= True)
FeaturesToConvert = ['Age','Annual_Income','Num_of_Loan','Num_of_Delayed_Payment','Changed_Credit_Limit','Outstanding_Debt','Amount_invested_monthly','Monthly_Balance']
df_cleaned = train.drop_duplicates(subset='ID',inplace= True)
for feature in FeaturesToConvert :
  train[feature] = train[feature].str.strip('-_')

for feature in FeaturesToConvert:
  train[feature] = train[feature].replace({'':np.nan})

for feature in FeaturesToConvert:
  train[feature] = train[feature].astype('float64')
  train['Monthly_Inhand_Salary']= train['Monthly_Inhand_Salary'].fillna(method='pad')
#le = LabelEncoder()
#train.Occupation = le.fit_transform(df.Occupation)
#train.head()
#cols = ['workex', 'status', 'hsc_s', 'degree_t']

#train[cols] =  train[cols].apply(LabelEncoder().fit_transform)

#train.head()
train.describe()

#for i in train.columns:
  #print(train[i].value_counts())
  #print('*'*50)

#sns.countplot(train['Credit_Score'])
#scaler = MinMaxScaler()
#col_float = ['Age','Annual_Income','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt','Credit_History_Age','Total_EMI_per_month','Monthly_Balance']
#for i in df_cleaned[col_float]:
 # df_cleaned[i] = scaler.fit_transform(df_cleaned[[i]])
  #df_cleaned.head
# Out:
# <ipython-input-60-c7faf3fd8316>:9: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('train.csv')
#                  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000   1.000000e+05          100000.000000      100000.000000
# mean      119.509700   1.764157e+05            4196.144246          17.091280
# std       684.757313   1.429618e+06            3187.848468         117.404834
# min        14.000000   7.005930e+03             303.645417          -1.000000
# 25%        25.000000   1.945750e+04            1625.558333           3.000000
# 50%        34.000000   3.757861e+04            3089.544583           6.000000
# 75%        42.000000   7.279092e+04            5957.715000           7.000000
# max      8698.000000   2.419806e+07           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate    Num_of_Loan  Delay_from_due_date  \
# ...
